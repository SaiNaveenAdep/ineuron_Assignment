# %%
#1. In the below elements which of them are values or an expression? eg:- values can be
#integer or string and expressions will be mathematical operators.

* = EXPRESSION
&#39;hello&#39 = STRING
-87.8 = INTEGER
- = EXPRESSION
/ = EXPRESSION
+ = EXPRESSION
6 = INTEGER

# %%
#2. What is the difference between string and variable?

string = what ever expression or values comes under the " " or '' is string.it may be name or values or numbers or symbols

variable = the content that hold's the strings is variable

ex:   name = ("sainaveen")

    here name is variable 
    "sainaveen" is string

# %%
#3.Describe three different data types.
Text-type= str
Numaric-type = int,float,complex
sequence-type = list,tuples,range

STRING (str)--> holds the strings like "1234",'ineuron', "sainaveen"

STRING EXAMPLE:
print("ineuron")
print("full stack data science")
#######################################################################

INTEGER (int)-->holds numarical values 
EXAMPLE:
    a = 10
    b = 20
    c = 30
    
FLOAT (float)--> float holds decimal values
EXAMPLE:
    x = 1.2
    y = 2.1
    z = 21.5


COMPLEX (complex)--> complex holds the real numbers and alphabets which are help to measure quantities like liters, kilograms, voltages..etc
Example:
    A = (4L +67L)
    B = 6748Kg
    D = 120V

    
############################################################################################

sequence-type tuples,range

list--> can stote the values and variable denoted my []--> square bracket

EXample: name=[1,2,3,4,5,6,"ineuron","true","SAINAVEEN"]
    
tuples--> can also can store values and variable denoted by ()--> curve bracket
#NOTE: tuples are immutable
EXAMPLE: t(1,2,3,4,5,"car","toyota","class")
    
Range--> hold the numbers from o to n
EXAMPLE: range(1,2,6)

# %%
#4.What is an expression made up of? What do all expressions do?


expression is the combination of variables,values,datatypes,boolean..etc
Expresion which add meaning or values to the given content

EXAMPLE: 
    a = 10
    b = 20
    c = a+b
    print(a+b)
    
    +,-,*,/, -->Mathametical Exprestion
    
    line no 9,10 its called expression

# %%
#5.This assignment statements, like spam = 10. What is the difference between an
expression and a statement?

EXPRESTION is like which add value to the variable,
EXAMPLE:
     a = 1
     b = 10
     c = a+b
print(a+b)
print(a-b)

which print 11

STATEMENT: which means that what ever writen  by the user can not modified my the compiler or interpreter
EXAMPLE: print("ineuron is the best place for Datascience course")
         print("ineuron si eht tseb place rof dataScience COURSE")
    
    from the aboue example  what ever user write's the system is going to accept with out any error!!
    
    

    
were as in expression its follow some stands if we change the symbol from + to - the output will be different with the same input's
but different output.

# %%
#6. After running the following code, what does the variable bacon contain?
#bacon = 22
#bacon + 1

The variable bacon contain the value =23
we are assigning 22 to bacon variable
and adding +1 to the variable bacon so result will be = 23

beacuse it's adding the 1 to 22

# %%
#7. What should the values of the following two terms be?

# 'spam'+'spam+spam'
#'spam'*3


from 'spam' + 'spamspam'
we get 'spamspamspam'

here the addition (+) operation adding or concatinating the three string into 

from 'spam'*3
we get 'spamspamspam'
here the multipcation (*) operation multiplying the 'spam' string to 3 times


output are same but the way of operations are different

# %%
#8. Why is eggs a valid variable name while 100 is invalid?

variable's  follow certain standards that can be -> name's, alphabets,combination both but not numbers!!!

EXAMPLE

a3= 1
b=2
c =(a3+b)
print(c)

out put: 3

    
##############################################################
but not 

123apple = 10
321mango7 = 20
amount = apple2 + mango7
print(amount)

out put: SyntaxError: invalid syntax

# %%
#9.What three functions can be used to get the integer, floating-point number, or string
#version of a value?

int()-->THis function used to get integer value
float()--> This function is used to get float value
str()--> This function is used to get string value

Example's:

int(24)
float(1.2343)
str("This is my first Assigement in python basic")

# %%
#10. Why does this expression cause an error? How can you fix it?

#'I have eaten'  + 99 +  'burritos'

In this peace of code string only can concatenate or add only "str"+"str" or numaric + numaric  but not "str"+ numaric or numaric + "str"

It can through the TypeError
